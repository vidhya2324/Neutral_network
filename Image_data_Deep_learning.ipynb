# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhya2324/Neutral_network/blob/main/Image_data_Deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * image reading and conver into numpy
# * Resizing the image
# * Rgb into gray scale image

# %%
# getting the image from wget command
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2024-10-10 08:36:21--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 13.35.7.27, 13.35.7.2, 13.35.7.42, ...
# Connecting to tractive.com (tractive.com)|13.35.7.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   247KB/s    in 0.4s
#
# 2024-10-10 08:36:23 (247 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %% [markdown]
# #widely used image
#  * matplotlib
#  * opencv
#  * pillow

# %%
#import the neccessary libraries
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
#displayng the image from numpy   array
img_plot= plt.imshow(img)
plt.show()

# %% [markdown]
# #Resizing an image lsoing pillow libraries

# %%
from PIL import Image
img=Image.open('/content/dog.jpg')

# %%
img_resized=img.resize((200,200))

# %%
img_resized.save('/content/dog.jpg')

# %%
#displaying the image from numpy array
img_res=mpimg.imread('/content/dog.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %% [markdown]
# #convert the RGb to Grayscale using openCV

# %%
img=cv2.imread("/content/dog.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (200, 200)

# %%
from google.colab.patches import cv2_imshow

# %%
#display the grayscale image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
